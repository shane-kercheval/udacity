# %%
# !pip install oolearning --upgrade

# %%
import copy
import os
import oolearning as oo
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


from helpers import column_log, BinaryAucRocScore

pd.set_option('display.width', 500)
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
width = 10
plt.rcParams['figure.figsize'] = [width, width/1.333]

# %%
csv_file = '../census.csv'
target_variable = 'income'

explore = oo.ExploreClassificationDataset.from_csv(csv_file_path=csv_file,
                                                   target_variable=target_variable)
negative_class = '<=50K'
positive_class = '>50K'

explore.dataset.head(20)
# Out:
#     age         workclass education_level  education-num         marital-status         occupation   relationship                race     sex  capital-gain  capital-loss  hours-per-week native-country income
# 0   39   State-gov         Bachelors       13.0           Never-married          Adm-clerical       Not-in-family  White               Male    2174.0        0.0           40.0            United-States  <=50K
# 1   50   Self-emp-not-inc  Bachelors       13.0           Married-civ-spouse     Exec-managerial    Husband        White               Male    0.0           0.0           13.0            United-States  <=50K
# 2   38   Private           HS-grad         9.0            Divorced               Handlers-cleaners  Not-in-family  White               Male    0.0           0.0           40.0            United-States  <=50K
# 3   53   Private           11th            7.0            Married-civ-spouse     Handlers-cleaners  Husband        Black               Male    0.0           0.0           40.0            United-States  <=50K
# 4   28   Private           Bachelors       13.0           Married-civ-spouse     Prof-specialty     Wife           Black               Female  0.0           0.0           40.0            Cuba           <=50K
# 5   37   Private           Masters         14.0           Married-civ-spouse     Exec-managerial    Wife           White               Female  0.0           0.0           40.0            United-States  <=50K
# 6   49   Private           9th             5.0            Married-spouse-absent  Other-service      Not-in-family  Black               Female  0.0           0.0           16.0            Jamaica        <=50K
# 7   52   Self-emp-not-inc  HS-grad         9.0            Married-civ-spouse     Exec-managerial    Husband        White               Male    0.0           0.0           45.0            United-States  >50K
# 8   31   Private           Masters         14.0           Never-married          Prof-specialty     Not-in-family  White               Female  14084.0       0.0           50.0            United-States  >50K
# 9   42   Private           Bachelors       13.0           Married-civ-spouse     Exec-managerial    Husband        White               Male    5178.0        0.0           40.0            United-States  >50K
# 10  37   Private           Some-college    10.0           Married-civ-spouse     Exec-managerial    Husband        Black               Male    0.0           0.0           80.0            United-States  >50K
# 11  30   State-gov         Bachelors       13.0           Married-civ-spouse     Prof-specialty     Husband        Asian-Pac-Islander  Male    0.0           0.0           40.0            India          >50K
# 12  23   Private           Bachelors       13.0           Never-married          Adm-clerical       Own-child      White               Female  0.0           0.0           30.0            United-States  <=50K
# 13  32   Private           Assoc-acdm      12.0           Never-married          Sales              Not-in-family  Black               Male    0.0           0.0           50.0            United-States  <=50K
# 14  34   Private           7th-8th         4.0            Married-civ-spouse     Transport-moving   Husband        Amer-Indian-Eskimo  Male    0.0           0.0           45.0            Mexico         <=50K
# 15  25   Self-emp-not-inc  HS-grad         9.0            Never-married          Farming-fishing    Own-child      White               Male    0.0           0.0           35.0            United-States  <=50K
# 16  32   Private           HS-grad         9.0            Never-married          Machine-op-inspct  Unmarried      White               Male    0.0           0.0           40.0            United-States  <=50K
# 17  38   Private           11th            7.0            Married-civ-spouse     Sales              Husband        White               Male    0.0           0.0           50.0            United-States  <=50K
# 18  43   Self-emp-not-inc  Masters         14.0           Divorced               Exec-managerial    Unmarried      White               Female  0.0           0.0           45.0            United-States  >50K
# 19  40   Private           Doctorate       16.0           Married-civ-spouse     Prof-specialty     Husband        White               Male    0.0           0.0           60.0            United-States  >50K

# %%
def create_net_capital(x):
    temp = x.copy()
    temp['net capital'] = temp['capital-gain'] - temp['capital-loss']
    return temp

# %%
global_transformations = [
                         oo.ImputationTransformer(),
                         oo.StatelessColumnTransformer(columns=['capital-gain', 'capital-loss'],
                                                       custom_function=column_log),
                         oo.StatelessTransformer(custom_function=create_net_capital),
                         oo.CenterScaleTransformer(),
                         oo.DummyEncodeTransformer(oo.CategoricalEncoding.ONE_HOT)
]

# %%
params_dict = dict(
#    penalty=['l1', 'l2'],
    penalty_c=[0.001, 0.01, 0.05, 0.1, 1, 5, 8, 10, 12, 14, 30, 50],
)

grid = oo.HyperParamsGrid(params_dict=params_dict)
grid.params_grid
# Out:
#     penalty_c
# 0   0.001
# 1   0.010
# 2   0.050
# 3   0.100
# 4   1.000
# 5   5.000
# 6   8.000
# 7   10.000
# 8   12.000
# 9   14.000
# 10  30.000
# 11  50.000

# %%
hyper_param_object = oo.SvmLinearClassifierHP(
    # penalty_c=
    penalty='l2'
)

# %%
model=oo.SvmLinearClassifier()

# %%
repeats = 5
folds = 5

# %%
model_cache_directory = 'tuner_SVM'
resampler_cache_directory = 'tuner_SVM_resample_cache'

# %%
score_list = [oo.AucRocScore(positive_class=positive_class),
              oo.FBetaScore(converter=oo.TwoClassThresholdConverter(threshold=0.5,
                                                                    positive_class=positive_class),
                            beta=0.5),
              oo.SensitivityScore(converter=oo.TwoClassThresholdConverter(threshold=0.5,
                                                                          positive_class=positive_class)),
              oo.PositivePredictiveValueScore(converter=oo.TwoClassThresholdConverter(threshold=0.5,
                                                                                      positive_class=positive_class))]

# %%
# define/configure the resampler
resampler = oo.RepeatedCrossValidationResampler(model=model,  # using a Random Forest model
                                             transformations=global_transformations,
                                             scores=[s.clone() for s in score_list],
                                             folds=folds,
                                             repeats=repeats)
# define/configure the ModelTuner
tuner = oo.ModelTuner(resampler=resampler,
                      hyper_param_object=hyper_param_object,
                      model_persistence_manager=oo.LocalCacheManager(cache_directory=model_cache_directory),
                      resampler_persistence_manager=oo.LocalCacheManager(cache_directory=resampler_cache_directory),
                      #parallelization_cores=-1,
                      parallelization_cores=0,
                     )

# %%
tuner.tune(data_x=explore.dataset.drop(columns=target_variable),
           data_y=explore.dataset[target_variable],
           params_grid=grid)

# %%
params_dict
# Out:
# {'penalty_c': [0.001, 0.01, 0.05, 0.1, 1, 5, 8, 10, 12, 14, 30, 50]}

# %%
tuner.results.best_hyper_params
# Out:
# {'penalty_c': 1.0}

# %%
tuner.results.best_model_resampler_object.score_means
# Out:
# {'AUC_ROC': 0.8943953006812805,
#  'F_BETA': 0.6867508501071388,
#  'sensitivity': 0.5722524273401894,
#  'positive_predictive_value': 0.7229724481365413}

# %%
tuner.results.plot_resampled_stats()

# %%
tuner.results.plot_resampled_scores(metric=oo.Metric.AUC_ROC,
                                    x_axis_limits=(0.89, 0.91),
                                    show_one_ste_rule=True
                                   )

# %%
params_dict
# Out:
# {'penalty_c': [0.001, 0.01, 0.05, 0.1, 1, 5, 8, 10, 12, 14, 30, 50]}

# %%
tuner.results.best_hyper_params
# Out:
# {'penalty_c': 1.0}

# %%
assert False

# %% [markdown]
# # Retrain on Full Training

# %%
final_hyper_param_object = oo.SvmLinearClassifierHP(
                                                   penalty='l2',
                                                   penalty_c=10,
                                                  )

final_model = oo.SvmLinearClassifier()
final_transformations = [
                         # kaggle test file has white space around values
                         oo.StatelessColumnTransformer(columns=explore.categoric_features,
                                                       custom_function=lambda x: x.str.strip()),
                         oo.ImputationTransformer(),
                         oo.StatelessColumnTransformer(columns=['capital-gain', 'capital-loss'],
                                                       custom_function=column_log),
                         oo.StatelessTransformer(custom_function=create_net_capital),
                         oo.CenterScaleTransformer(),
                         oo.DummyEncodeTransformer(oo.CategoricalEncoding.ONE_HOT)
]

# %%
# use the ideal threshold for the evaluator in order to view ROC
evaluator = oo.TwoClassProbabilityEvaluator(converter=
                    oo.TwoClassThresholdConverter(positive_class=positive_class))

trainer = oo.ModelTrainer(model=final_model.clone(),
                          model_transformations=[t.clone() for t in final_transformations],
                          splitter=None,  # don't split, train on all data
                          evaluator=evaluator,
                          scores=[s.clone() for s in score_list])
trainer.train(data=explore.dataset, target_variable=target_variable, hyper_params=final_hyper_param_object.clone())

trainer.training_evaluator.all_quality_metrics
# Out:
# {'AUC ROC': 0.8956635796814907,
#  'AUC Precision/Recall': 0.7435704624809676,
#  'Kappa': 0.5388760079834191,
#  'F1 Score': 0.639580733715997,
#  'Two-Class Accuracy': 0.8403210826588828,
#  'Error Rate': 0.15967891734111717,
#  'True Positive Rate': 0.5716452533904354,
#  'True Negative Rate': 0.9288528253072265,
#  'False Positive Rate': 0.07114717469277357,
#  'False Negative Rate': 0.4283547466095646,
#  'Positive Predictive Value': 0.7258411691401382,
#  'Negative Predictive Value': 0.868086275587306,
#  'Prevalence': 0.2478439697492371,
#  'No Information Rate': 0.7521560302507629,
#  'Total Observations': 45222}

# %%
trainer.training_scores[0].value
# Out:
# 0.8956635796814907

# %%
trainer.training_evaluator.plot_roc_curve()

# %%
trainer.training_evaluator.plot_calibration()

# %%
csv_file = '../test_census.csv'
test_dataset = pd.read_csv(csv_file)
test_dataset.shape
# Out:
# (45222, 14)

# %%
test_dataset.head(100)
# Out:
#     Unnamed: 0   age          workclass education_level  education-num          marital-status          occupation     relationship                 race      sex  capital-gain  capital-loss  hours-per-week  native-country
# 0   0           21.0   Private            10th           6.0             Married-civ-spouse      Craft-repair        Husband          White                Male    0.0           0.0           40.0             United-States
# 1   1           49.0   Private            Bachelors      13.0            Married-civ-spouse      Adm-clerical        Wife             White                Female  0.0           0.0           40.0             United-States
# 2   2           44.0   Self-emp-not-inc   Assoc-acdm     12.0            Married-civ-spouse      Other-service       Wife             White                Female  0.0           0.0           99.0             United-States
# 3   3           34.0   Private            Bachelors      13.0            Married-civ-spouse      Sales               Husband          White                Male    7298.0        0.0           46.0             United-States
# 4   4           24.0   Private            HS-grad        9.0             Married-civ-spouse      Machine-op-inspct   Husband          White                Male    0.0           0.0           40.0             United-States
# 5   5           52.0   Private            7th-8th        4.0             Divorced                Priv-house-serv     Own-child        Black                Female  0.0           0.0           16.0             United-States
# 6   6           61.0   Private            7th-8th        4.0             Married-civ-spouse      Transport-moving    Husband          White                Male    0.0           0.0           50.0             United-States
# 7   7           24.0   Private            HS-grad        9.0             Married-civ-spouse      Craft-repair        Husband          White                Male    0.0           0.0           40.0             United-States
# 8   8           30.0   Private            HS-grad        9.0             Never-married           Handlers-cleaners   Not-in-family    White                Male    0.0           0.0           22.0             United-States
# 9   9           42.0   Local-gov          HS-grad        9.0             Married-civ-spouse      Exec-managerial     Husband          White                Male    0.0           0.0           60.0             United-States
# 10  10          47.0   Local-gov          Prof-school    15.0            Married-civ-spouse      Prof-specialty      Husband          White                Male    0.0           0.0           35.0             United-States
# 11  11          42.0   Self-emp-not-inc   Bachelors      13.0            Married-civ-spouse      Craft-repair        Husband          White                Male    15024.0       0.0           60.0             United-States
# 12  12          58.0   Self-emp-inc       HS-grad        9.0             Married-civ-spouse      Exec-managerial     Husband          White                Male    0.0           0.0           40.0             United-States
# 13  13          28.0   Self-emp-not-inc   Some-college   10.0            Never-married           Prof-specialty      Own-child        White                Male    0.0           0.0           30.0             United-States
# 14  14          30.0   Self-emp-inc       Bachelors      13.0            Married-civ-spouse      Sales               Husband          White                Male    0.0           0.0           52.0             United-States
# 15  15          48.0   Local-gov          Masters        14.0            Married-civ-spouse      Prof-specialty      Husband          White                Male    0.0           0.0           40.0             United-States
# 16  16          55.0   Private            HS-grad        9.0             Married-civ-spouse      Craft-repair        Husband          White                Male    0.0           0.0           40.0             United-States
# 17  17          47.0   Private            Some-college   10.0            Divorced                Adm-clerical        Unmarried        White                Female  0.0           0.0           42.0             United-States
# 18  18          41.0   Private            Some-college   10.0            Separated               Adm-clerical        Not-in-family    White                Female  0.0           0.0           38.0             United-States
# 19  19          20.0   Self-emp-not-inc   HS-grad        9.0             Never-married           Farming-fishing     Own-child        White                Male    0.0           0.0           40.0             United-States
# 20  20          21.0   Private            Some-college   10.0            Never-married           Craft-repair        Own-child        White                Male    0.0           1719.0        30.0             United-States
# 21  21          34.0   Private            Bachelors      13.0            Married-civ-spouse      Exec-managerial     Husband          White                Male    5178.0        0.0           55.0             United-States
# 22  22          43.0   Private            Bachelors      13.0            Married-civ-spouse      Adm-clerical        Husband          White                Male    0.0           0.0           40.0             United-States
# 23  23          27.0   Private            HS-grad        9.0             Never-married           Handlers-cleaners   Own-child        White                Female  0.0           0.0           40.0             United-States
# 24  24          32.0   State-gov          Bachelors      13.0            Married-civ-spouse      Protective-serv     Husband          White                Male    0.0           1887.0        45.0             United-States
# 25  25          30.0   Private            Assoc-voc      11.0            Married-civ-spouse      Prof-specialty      Husband          White                Male    0.0           0.0           40.0             United-States
# 26  26          27.0   Private            Some-college   10.0            Never-married           Handlers-cleaners   Not-in-family    Black                Male    0.0           0.0           50.0             United-States
# 27  27          54.0   Private            Bachelors      13.0            Married-civ-spouse      Exec-managerial     Husband          White                Male    0.0           0.0           40.0             United-States
# 28  28          23.0   Private            HS-grad        9.0             Never-married           Priv-house-serv     Own-child        White                Male    0.0           0.0           40.0             United-States
# 29  29          30.0   Private            HS-grad        9.0             Never-married           Other-service       Unmarried        White                Female  0.0           0.0           40.0             United-States
# 30  30          27.0   Private            Bachelors      13.0            Never-married           Tech-support        Unmarried        Black                Female  0.0           0.0           40.0             United-States
# 31  31          59.0   Private            HS-grad        9.0             Married-spouse-absent   Priv-house-serv     Not-in-family    White                Female  0.0           0.0           36.0             Poland
# 32  32          25.0   Private            HS-grad        9.0             Never-married           Other-service       Own-child        White                Female  0.0           0.0           25.0             United-States
# 33  33          32.0   Self-emp-not-inc   Some-college   10.0            Married-civ-spouse      Farming-fishing     Husband          White                Male    0.0           0.0           50.0             United-States
# 34  34          35.0   Private            HS-grad        9.0             Never-married           Craft-repair        Not-in-family    White                Male    0.0           0.0           70.0             United-States
# 35  35          53.0   Private            Bachelors      13.0            Married-civ-spouse      Exec-managerial     Husband          White                Male    0.0           0.0           40.0             United-States
# 36  36          35.0   Self-emp-inc       HS-grad        9.0             Married-civ-spouse      Other-service       Husband          White                Male    0.0           0.0           50.0             Puerto-Rico
# 37  37          49.0   Self-emp-not-inc   Bachelors      13.0            Never-married           Sales               Not-in-family    White                Male    0.0           0.0           45.0             United-States
# 38  38          38.0   Private            HS-grad        9.0             Separated               Craft-repair        Unmarried        White                Female  0.0           0.0           35.0             United-States
# 39  39          20.0   Private            Some-college   10.0            Never-married           Sales               Not-in-family    White                Male    0.0           0.0           45.0             United-States
# 40  40          44.0   Local-gov          Bachelors      13.0            Married-civ-spouse      Protective-serv     Husband          White                Male    0.0           0.0           56.0             United-States
# 41  41          19.0   Private            Some-college   10.0            Never-married           Adm-clerical        Own-child        White                Female  0.0           0.0           16.0             United-States
# 42  42          53.0   Private            11th           7.0             Married-civ-spouse      Craft-repair        Husband          White                Male    0.0           0.0           45.0             United-States
# 43  43          65.0   Private            Some-college   10.0            Divorced                Other-service       Not-in-family    Asian-Pac-Islander   Female  0.0           0.0           15.0             United-States
# 44  44          55.0   Private            HS-grad        9.0             Divorced                Sales               Unmarried        White                Female  0.0           0.0           37.0             United-States
# 45  45          22.0   Private            Some-college   10.0            Never-married           Tech-support        Own-child        White                Male    0.0           0.0           40.0             United-States
# 46  46          36.0   Local-gov          Some-college   10.0            Married-civ-spouse      Prof-specialty      Husband          Black                Male    0.0           1887.0        40.0             Jamaica
# 47  47          52.0   Private            1st-4th        2.0             Married-civ-spouse      Farming-fishing     Husband          White                Male    0.0           0.0           56.0             Mexico
# 48  48          37.0   Private            HS-grad        9.0             Divorced                Adm-clerical        Unmarried        White                Female  0.0           0.0           37.0             United-States
# 49  49          26.0   Private            HS-grad        9.0             Never-married           Adm-clerical        Own-child        White                Male    0.0           0.0           40.0             United-States
# 50  50          64.0   State-gov          Some-college   10.0            Separated               Adm-clerical        Not-in-family    White                Female  0.0           0.0           65.0             United-States
# 51  51          49.0   Private            HS-grad        9.0             Divorced                Other-service       Not-in-family    White                Female  0.0           0.0           40.0             United-States
# 52  52          21.0   Private            Some-college   10.0            Never-married           Sales               Not-in-family    White                Male    0.0           0.0           40.0             United-States
# 53  53          24.0   Private            Assoc-voc      11.0            Never-married           Other-service       Own-child        White                Female  0.0           0.0           35.0             United-States
# 54  54          42.0   Private            Assoc-voc      11.0            Married-civ-spouse      Adm-clerical        Husband          White                Male    2407.0        0.0           40.0             United-States
# 55  55          41.0   Private            HS-grad        9.0             Married-civ-spouse      Sales               Husband          White                Male    0.0           0.0           49.0             United-States
# 56  56          41.0   Private            Bachelors      13.0            Never-married           Prof-specialty      Not-in-family    White                Female  0.0           1876.0        40.0             United-States
# 57  57          50.0   Local-gov          11th           7.0             Never-married           Craft-repair        Unmarried        White                Male    0.0           0.0           40.0             United-States
# 58  58          41.0   Private            Bachelors      13.0            Married-civ-spouse      Sales               Husband          White                Male    0.0           0.0           48.0             United-States
# 59  59          24.0   Private            Bachelors      13.0            Never-married           Sales               Own-child        White                Male    0.0           0.0           40.0             United-States
# 60  60          30.0   Private            Some-college   10.0            Married-civ-spouse      Craft-repair        Husband          White                Male    0.0           0.0           40.0             United-States
# 61  61          38.0   Private            Some-college   10.0            Married-civ-spouse      Craft-repair        Husband          White                Male    0.0           0.0           40.0             United-States
# 62  62          22.0   Private            HS-grad        9.0             Married-spouse-absent   Sales               Not-in-family    White                Male    0.0           1719.0        40.0             United-States
# 63  63          53.0   Private            Some-college   10.0            Never-married           Exec-managerial     Not-in-family    Black                Female  0.0           0.0           40.0             United-States
# 64  64          52.0   Self-emp-not-inc   7th-8th        4.0             Married-civ-spouse      Transport-moving    Husband          White                Male    0.0           0.0           40.0             United-States
# 65  65          47.0   Private            HS-grad        9.0             Separated               Adm-clerical        Unmarried        White                Female  0.0           0.0           40.0             United-States
# 66  66          43.0   Private            Some-college   10.0            Divorced                Adm-clerical        Unmarried        Black                Female  0.0           0.0           35.0             United-States
# 67  67          59.0   Private            11th           7.0             Widowed                 Transport-moving    Unmarried        White                Female  0.0           0.0           40.0             United-States
# 68  68          34.0   Private            Assoc-acdm     12.0            Never-married           Adm-clerical        Not-in-family    Asian-Pac-Islander   Female  8614.0        0.0           60.0             United-States
# 69  69          18.0   Private            HS-grad        9.0             Never-married           Other-service       Own-child        White                Female  0.0           0.0           40.0             United-States
# 70  70          53.0   Private            Some-college   10.0            Married-civ-spouse      Craft-repair        Husband          White                Male    0.0           0.0           40.0             United-States
# 71  71          56.0   Private            HS-grad        9.0             Married-civ-spouse      Other-service       Husband          White                Male    0.0           0.0           50.0             Yugoslavia
# 72  72          40.0   Federal-gov        Some-college   10.0            Divorced                Exec-managerial     Not-in-family    Black                Female  0.0           0.0           40.0             United-States
# 73  73          28.0   Private            HS-grad        9.0             Never-married           Sales               Unmarried        White                Female  0.0           0.0           70.0             United-States
# 74  74          22.0   Private            Bachelors      13.0            Never-married           Sales               Own-child        White                Female  0.0           0.0           8.0              United-States
# 75  75          49.0   Federal-gov        Some-college   10.0            Married-civ-spouse      Adm-clerical        Husband          White                Male    0.0           0.0           40.0             United-States
# 76  76          34.0   Private            HS-grad        9.0             Divorced                Adm-clerical        Unmarried        Black                Female  0.0           0.0           40.0             United-States
# 77  77          58.0   Self-emp-inc       10th           6.0             Married-civ-spouse      Transport-moving    Wife             White                Female  0.0           0.0           40.0             United-States
# 78  78          60.0   Private            HS-grad        9.0             Married-civ-spouse      Handlers-cleaners   Husband          White                Male    0.0           0.0           40.0             United-States
# 79  79          50.0   Private            Masters        14.0            Married-civ-spouse      Prof-specialty      Husband          White                Male    15024.0       0.0           45.0             United-States
# 80  80          23.0   Private            HS-grad        9.0             Married-civ-spouse      Machine-op-inspct   Husband          White                Male    0.0           0.0           50.0             United-States
# 81  81          27.0   Federal-gov        Some-college   10.0            Divorced                Adm-clerical        Other-relative   Black                Female  0.0           0.0           50.0             United-States
# 82  82          47.0   Self-emp-not-inc   Some-college   10.0            Divorced                Craft-repair        Not-in-family    White                Male    0.0           0.0           40.0             United-States
# 83  83          50.0   Private            Some-college   10.0            Divorced                Other-service       Not-in-family    White                Female  0.0           0.0           15.0             United-States
# 84  84          25.0   Private            HS-grad        9.0             Never-married           Exec-managerial     Own-child        Black                Male    0.0           0.0           40.0             United-States
# 85  85          29.0   Private            Some-college   10.0            Married-civ-spouse      Adm-clerical        Wife             White                Female  7298.0        0.0           50.0             United-States
# 86  86          32.0   State-gov          Assoc-acdm     12.0            Married-civ-spouse      Other-service       Husband          White                Male    0.0           0.0           35.0             United-States
# 87  87          60.0   Self-emp-not-inc   Some-college   10.0            Married-civ-spouse      Other-service       Wife             Black                Female  0.0           0.0           50.0             United-States
# 88  88          23.0   Self-emp-inc       HS-grad        9.0             Never-married           Adm-clerical        Not-in-family    White                Female  0.0           0.0           40.0             United-States
# 89  89          36.0   Private            HS-grad        9.0             Married-civ-spouse      Exec-managerial     Husband          White                Male    0.0           0.0           40.0             United-States
# 90  90          38.0   Private            HS-grad        9.0             Never-married           Farming-fishing     Not-in-family    White                Male    0.0           0.0           60.0             United-States
# 91  91          18.0   Private            Some-college   10.0            Never-married           Exec-managerial     Not-in-family    Black                Male    0.0           0.0           40.0             United-States
# 92  92          49.0   Self-emp-inc       Some-college   10.0            Divorced                Sales               Not-in-family    White                Male    0.0           0.0           25.0             United-States
# 93  93          40.0   Private            Some-college   10.0            Separated               Exec-managerial     Not-in-family    Black                Male    0.0           0.0           40.0             United-States
# 94  94          26.0   State-gov          Bachelors      13.0            Never-married           Adm-clerical        Not-in-family    White                Female  0.0           0.0           20.0             United-States
# 95  95          48.0   Local-gov          Masters        14.0            Separated               Prof-specialty      Not-in-family    White                Male    0.0           1876.0        50.0             United-States
# 96  96          40.0   Local-gov          Some-college   10.0            Never-married           Exec-managerial     Not-in-family    White                Male    0.0           0.0           40.0             United-States
# 97  97          32.0   Private            Bachelors      13.0            Married-civ-spouse      Prof-specialty      Husband          Asian-Pac-Islander   Male    0.0           0.0           40.0             United-States
# 98  98          24.0   Private            HS-grad        9.0             Never-married           Adm-clerical        Unmarried        White                Male    0.0           0.0           50.0             United-States
# 99  99          72.0   Private            Doctorate      16.0            Never-married           Prof-specialty      Not-in-family    White                Male    0.0           0.0           30.0             United-States

# %%
indexes = test_dataset['Unnamed: 0']

predictions = trainer.predict(test_dataset.drop(columns='Unnamed: 0'))
predictions.head(10)
# Out:
#       <=50K      >50K
# 0  0.888592  0.111408
# 1  0.354781  0.645219
# 2  0.509872  0.490128
# 3  0.070885  0.929115
# 4  0.853770  0.146230
# 5  0.997082  0.002918
# 6  0.871801  0.128199
# 7  0.834884  0.165116
# 8  0.987212  0.012788
# 9  0.527817  0.472183

# %% [markdown]
# # Results

# %% [markdown]
# ## 1)
#
# Kaggle Public: ``
#
# File: `submission_x_SVM.csv`
#
# Parameters:
#
# ```
#
# ```
#
# Originally had Mean Resampler Results of:
#
# ```
#
# ```

# %%
""
