# %% [markdown]
# here, I use my own framework, **`oo-learning`** (https://github.com/shane-kercheval/oo-learning) which I designed for common workflows of data science

# %% [markdown]
# # Set Up Environment

# %%
# !pip install oolearning --upgrade

# %%
from oolearning import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
width = 7
plt.rcParams['figure.figsize'] = [width, width/1.333]

# %% [markdown]
# # Import Data

# %%
csv_file = '../census.csv'
target_variable = 'income'
explore = ExploreClassificationDataset.from_csv(csv_file_path=csv_file,
                                                target_variable=target_variable)

# %%
explore.dataset.head(20)
# Out:
#     age         workclass education_level  education-num  \
# 0   39   State-gov         Bachelors       13.0
# 1   50   Self-emp-not-inc  Bachelors       13.0
# 2   38   Private           HS-grad         9.0
# 3   53   Private           11th            7.0
# 4   28   Private           Bachelors       13.0
# 5   37   Private           Masters         14.0
# 6   49   Private           9th             5.0
# 7   52   Self-emp-not-inc  HS-grad         9.0
# 8   31   Private           Masters         14.0
# 9   42   Private           Bachelors       13.0
# 10  37   Private           Some-college    10.0
# 11  30   State-gov         Bachelors       13.0
# 12  23   Private           Bachelors       13.0
# 13  32   Private           Assoc-acdm      12.0
# 14  34   Private           7th-8th         4.0
# 15  25   Self-emp-not-inc  HS-grad         9.0
# 16  32   Private           HS-grad         9.0
# 17  38   Private           11th            7.0
# ...

# %% [markdown]
# **Features**
# - `age`: Age
# - `workclass`: Working Class (Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked)
# - `education_level`: Level of Education (Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool)
# - `education-num`: Number of educational years completed
# - `marital-status`: Marital status (Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse)
# - `occupation`: Work Occupation (Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces)
# - `relationship`: Relationship Status (Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried)
# - `race`: Race (White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black)
# - `sex`: Sex (Female, Male)
# - `capital-gain`: Monetary Capital Gains
# - `capital-loss`: Monetary Capital Losses
# - `hours-per-week`: Average Hours Per Week Worked
# - `native-country`: Native Country (United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands)
#
# **Target Variable**
# - `income`: Income Class (<=50K, >50K)

# %% [markdown]
# # Summary

# %%
explore.unique_values('income')
# Out:
#         freq   perc
# <=50K  34014  0.752
# >50K   11208  0.248

# %%
explore.numeric_summary()
# Out:
#                 count  nulls  perc_nulls  num_zeros  perc_zeros      mean  \
# age             45222  0      0.0         0          0.000       38.548
# education-num   45222  0      0.0         0          0.000       10.118
# capital-gain    45222  0      0.0         41432      0.916       1101.430
# capital-loss    45222  0      0.0         43082      0.953       88.595
# hours-per-week  45222  0      0.0         0          0.000       40.938
#
#                   st_dev  coef of var  skewness  kurtosis   min   10%   25%  \
# age             13.218    0.343        0.533    -0.156     17.0  22.0  28.0
# education-num   2.553     0.252       -0.311     0.635     1.0   7.0   9.0
# capital-gain    7506.430  6.815        11.789    150.151   0.0   0.0   0.0
# capital-loss    404.956   4.571        4.516     19.364    0.0   0.0   0.0
# hours-per-week  12.008    0.293        0.341     3.201     1.0   25.0  40.0
#
#                  50%   75%   90%      max
# ...

# %%
explore.categoric_summary()
# Out:
#                  count  nulls  perc_nulls                 top  unique  \
# workclass        45222  0      0.0         Private             7
# education_level  45222  0      0.0         HS-grad             16
# marital-status   45222  0      0.0         Married-civ-spouse  7
# occupation       45222  0      0.0         Craft-repair        14
# relationship     45222  0      0.0         Husband             6
# race             45222  0      0.0         White               5
# sex              45222  0      0.0         Male                2
# native-country   45222  0      0.0         United-States       41
# income           45222  0      0.0         <=50K               2
#
#                  perc_unique
# workclass        0.000
# education_level  0.000
# marital-status   0.000
# occupation       0.000
# relationship     0.000
# race             0.000
# sex              0.000
# native-country   0.001
# income           0.000

# %% [markdown]
# # Numeric Features

# %% [markdown]
# ## Correlations

# %%
explore.plot_correlation_heatmap()

# %% [markdown]
# ## General Distributions

# %%
explore.plot_scatterplot_numerics()

# %% [markdown]
# ## Features

# %% [markdown]
# ### age

# %%
explore.plot_histogram(numeric_feature='age', num_bins=20)

# %%
explore.plot_boxplot(numeric_feature='age')

# %%
explore.plot_against_target(feature='age')

# %%
explore.plot_histogram_against_target(numeric_feature='age')

# %% [markdown]
# ### education-num

# %%
explore.plot_histogram(numeric_feature='education-num', num_bins=15)

# %%
explore.plot_boxplot(numeric_feature='education-num')

# %%
explore.plot_against_target(feature='education-num')

# %%
explore.plot_histogram_against_target(numeric_feature='education-num')

# %% [markdown]
# ### capital-gain

# %%
explore.plot_histogram(numeric_feature='capital-gain', num_bins=20)

# %%
explore.plot_histogram(numeric_feature='capital-gain', num_bins=20)
plt.ylim(0, 1000)
# Out:
# (0, 1000)

# %%
explore.plot_boxplot(numeric_feature='capital-gain')

# %%
explore.plot_against_target(feature='capital-gain')

# %%
explore.plot_histogram_against_target(numeric_feature='capital-gain')

# %% [markdown]
# ### capital-loss

# %%
explore.plot_histogram(numeric_feature='capital-loss', num_bins=20)

# %%
explore.plot_boxplot(numeric_feature='capital-loss')

# %%
explore.plot_against_target(feature='capital-loss')

# %%
explore.plot_histogram_against_target(numeric_feature='capital-loss')

# %% [markdown]
# ### hours-per-week

# %%
explore.plot_histogram(numeric_feature='hours-per-week', num_bins=20)

# %%
explore.plot_boxplot(numeric_feature='hours-per-week')

# %%
explore.plot_against_target(feature='hours-per-week')

# %%
explore.plot_histogram_against_target(numeric_feature='hours-per-week')

# %%
# see what log transformation would do
transformer = StatelessColumnTransformer(columns=['capital-gain', 'capital-loss'],
                                         custom_function=lambda x: np.log(x + 1))
transformed_data = transformer.fit_transform(data_x=explore.dataset)

# %%
explore.dataset['capital-gain'].hist(bins=15)
plt.ylim(0, 2000)
# Out:
# (0, 2000)

# %%
transformed_data['capital-gain'].hist(bins=15)
plt.ylim(0, 2000)
# Out:
# (0, 2000)

# %%
explore.dataset['capital-loss'].hist(bins=15)
plt.ylim(0, 2000)
# Out:
# (0, 2000)

# %%
transformed_data['capital-loss'].hist(bins=15)
plt.ylim(0, 2000)
# Out:
# (0, 2000)

# %% [markdown]
# # Categoric Features

# %% [markdown]
# ## workclass

# %%
explore.unique_values(categoric_feature='workclass')
# Out:
#                    freq   perc
# Private           33307  0.737
# Self-emp-not-inc  3796   0.084
# Local-gov         3100   0.069
# State-gov         1946   0.043
# Self-emp-inc      1646   0.036
# Federal-gov       1406   0.031
# Without-pay       21     0.000

# %%
explore.plot_unique_values(categoric_feature='workclass')

# %%
explore.plot_against_target(feature='workclass')

# %% [markdown]
# ## education_level

# %%
education_levels_ordered = ['Preschool', '1st-4th', '5th-6th', '7th-8th', '9th',
                            '10th', '11th', '12th', 'HS-grad', 'Some-college',
                            'Assoc-voc', 'Assoc-acdm', 'Prof-school', 'Bachelors',
                            'Masters', 'Doctorate']
explore.set_level_order(categoric_feature='education_level', levels=education_levels_ordered)

# %%
explore.unique_values(categoric_feature='education_level', sort_by_feature=True)
# Out:
#                freq   perc
# Preschool     72     0.002
# 1st-4th       222    0.005
# 5th-6th       449    0.010
# 7th-8th       823    0.018
# 9th           676    0.015
# 10th          1223   0.027
# 11th          1619   0.036
# 12th          577    0.013
# HS-grad       14783  0.327
# Some-college  9899   0.219
# Assoc-voc     1959   0.043
# Assoc-acdm    1507   0.033
# Prof-school   785    0.017
# Bachelors     7570   0.167
# Masters       2514   0.056
# Doctorate     544    0.012

# %%
explore.plot_unique_values(categoric_feature='education_level', sort_by_feature=True)

# %%
explore.plot_against_target(feature='education_level')

# %% [markdown]
# ## marital-status

# %%
explore.unique_values(categoric_feature='marital-status', sort_by_feature=True)
# Out:
#                         freq   perc
# Divorced               6297   0.139
# Married-AF-spouse      32     0.001
# Married-civ-spouse     21055  0.466
# Married-spouse-absent  552    0.012
# Never-married          14598  0.323
# Separated              1411   0.031
# Widowed                1277   0.028

# %%
explore.plot_unique_values(categoric_feature='marital-status', sort_by_feature=True)

# %%
explore.plot_against_target(feature='marital-status')

# %% [markdown]
# ## occupation

# %%
explore.unique_values(categoric_feature='occupation', sort_by_feature=True)
# Out:
#                    freq   perc
# Adm-clerical       5540  0.123
# Armed-Forces       14    0.000
# Craft-repair       6020  0.133
# Exec-managerial    5984  0.132
# Farming-fishing    1480  0.033
# Handlers-cleaners  2046  0.045
# Machine-op-inspct  2970  0.066
# Other-service      4808  0.106
# Priv-house-serv    232   0.005
# Prof-specialty     6008  0.133
# Protective-serv    976   0.022
# Sales              5408  0.120
# Tech-support       1420  0.031
# Transport-moving   2316  0.051

# %%
explore.plot_unique_values(categoric_feature='occupation', sort_by_feature=True)

# %%
explore.plot_against_target(feature='occupation')

# %% [markdown]
# ## relationship

# %%
explore.unique_values(categoric_feature='relationship', sort_by_feature=True)
# Out:
#                  freq   perc
# Husband         18666  0.413
# Not-in-family   11702  0.259
# Other-relative  1349   0.030
# Own-child       6626   0.147
# Unmarried       4788   0.106
# Wife            2091   0.046

# %%
explore.plot_unique_values(categoric_feature='relationship', sort_by_feature=True)

# %%
explore.plot_against_target(feature='relationship')

# %% [markdown]
# ## race

# %%
explore.unique_values(categoric_feature='race', sort_by_feature=True)
# Out:
#                      freq   perc
# Amer-Indian-Eskimo  435    0.010
# Asian-Pac-Islander  1303   0.029
# Black               4228   0.093
# Other               353    0.008
# White               38903  0.860

# %%
explore.plot_unique_values(categoric_feature='race', sort_by_feature=True)

# %%
explore.plot_against_target(feature='race')

# %% [markdown]
# ## sex

# %%
explore.unique_values(categoric_feature='sex', sort_by_feature=True)
# Out:
#          freq   perc
# Female  14695  0.325
# Male    30527  0.675

# %%
explore.plot_unique_values(categoric_feature='sex', sort_by_feature=True)

# %%
explore.plot_against_target(feature='sex')

# %% [markdown]
# ## native-country

# %%
explore.unique_values(categoric_feature='native-country', sort_by_feature=True)
# Out:
#                              freq   perc
# Cambodia                    26     0.001
# Canada                      163    0.004
# China                       113    0.002
# Columbia                    82     0.002
# Cuba                        133    0.003
# Dominican-Republic          97     0.002
# Ecuador                     43     0.001
# El-Salvador                 147    0.003
# England                     119    0.003
# France                      36     0.001
# Germany                     193    0.004
# Greece                      49     0.001
# Guatemala                   86     0.002
# Haiti                       69     0.002
# Holand-Netherlands          1      0.000
# Honduras                    19     0.000
# Hong                        28     0.001
# Hungary                     18     0.000
# India                       147    0.003
# Iran                        56     0.001
# Ireland                     36     0.001
# Italy                       100    0.002
# ...

# %% [markdown]
# # Look at the Kaggle Test Dataset
#
# We want to figure out if there are missing values, etc.

# %%
csv_file = '../test_census.csv'
explore_test = ExploreClassificationDataset.from_csv(csv_file_path=csv_file, target_variable='native-country')

# %%
explore_test.numeric_summary()
# Out:
#                 count  nulls  perc_nulls  num_zeros  perc_zeros       mean  \
# Unnamed: 0      45222  0      0.0         1          0.000       22610.500
# age             45205  17     0.0         0          0.000       38.550
# education-num   45208  14     0.0         0          0.000       10.119
# capital-gain    45207  15     0.0         41418      0.916       1099.584
# capital-loss    45205  17     0.0         43066      0.952       88.596
# hours-per-week  45209  13     0.0         0          0.000       40.939
#
#                    st_dev  coef of var  skewness  kurtosis   min     10%  \
# Unnamed: 0      13054.611  0.577        0.000    -1.200     0.0   4522.1
# age             13.219     0.343        0.533    -0.156     17.0  22.0
# education-num   2.553      0.252       -0.311     0.635     1.0   7.0
# capital-gain    7493.227   6.815        11.805    150.625   0.0   0.0
# capital-loss    404.976    4.571        4.516     19.365    0.0   0.0
# ...

# %%
explore_test.categoric_summary()
# Out:
#                  count  nulls  perc_nulls                 top  unique  \
# workclass        45200  22     0.0         Private             7
# education_level  45202  20     0.0         HS-grad             16
# marital-status   45201  21     0.0         Married-civ-spouse  7
# occupation       45200  22     0.0         Craft-repair        14
# relationship     45206  16     0.0         Husband             6
# race             45203  19     0.0         White               5
# sex              45203  19     0.0         Male                2
# native-country   45206  16     0.0         United-States       41
#
#                  perc_unique
# workclass        0.000
# education_level  0.000
# marital-status   0.000
# occupation       0.000
# relationship     0.000
# race             0.000
# sex              0.000
# native-country   0.001

# %%
set(explore.dataset['native-country'].unique()).symmetric_difference(set(explore_test.dataset['native-country'].unique()))
# Out:
# {nan}
